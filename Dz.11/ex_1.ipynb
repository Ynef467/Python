# %% [markdown]
# Задача 1. Постройте график функции
#
# 𝑓 𝑥 = 5𝑥^2 + 10𝑥 − 30
#
# По графику определите, при каких значения x значение функции отрицательно.

# %%
from sympy import *

# %%
x = symbols('x')

# %% [markdown]
# ## определение функции

# %%
f = 5*x*x+10*x-30

# %% [markdown]
# график функции

# %%
p1 = plot(f)

# %% [markdown]
# точки пересечения графика с осью абсцисс

# %%
solve(f)
# Out:
# [-1 + sqrt(7), -sqrt(7) - 1]

# %% [markdown]
# меджду точками пересечения с осью абсцисс значение функции отрицательно

# %% [markdown]
# ## производная

# %%
derivative_p1 = f.diff(x)

# %% [markdown]
# ## график производной

# %%
p_diff = plot(derivative_p1)

# %% [markdown]
# точка пересечения графика производной с осью абсцисс

# %%
solve(derivative_p1)
# Out:
# [-1]

# %% [markdown]
# - -1 - Точка экстремума функции f
# - x < -1 функция убывает
# - x > -1 функция возрастает
